# %%
# 在 jupyter 中绘图需要添加
# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# ## 1、Matplotlib 架构

# %%
# Backend
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %% [markdown]
# ## 2、基本图表的绘制

# %%
import matplotlib.pyplot as plt

# %%
# 使用 matplotlib.pyplot 直接绘制
plt.plot(3, 2, '*')

# %%
plt.Figure()
plt.plot(2, 2, 'o')
# ax = plt.gca()
